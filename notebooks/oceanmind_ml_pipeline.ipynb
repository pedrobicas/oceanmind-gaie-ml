# %% [markdown]
# # OceanMind — Pipeline de Machine Learning (GAIE)
# Notebook para treinamento, comparação de modelos e análise do risco oceânico.

# %%
import pandas as pd
df = pd.read_csv('../data/oceanmind_dataset.csv')
df.head()

# %%
df.shape, df['ocean_risk_level'].value_counts()

# %% [markdown]
# ## Treinamento dos modelos
# O treinamento completo está no script `src/train_models.py`.

# %%
import sys, os
os.chdir('..')
# !python src/train_models.py

# %% [markdown]
# ## SHAP
# Execute a análise de interpretabilidade.

# %%
# !python src/shap_analysis.py
